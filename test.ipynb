# %%
import sys
sys.path.append('./diffusechain')

# %%
from diffusechain import Automatic1111

api = Automatic1111(host='127.0.0.1',
                        port=7860,
                        sampler='Euler a',
                        steps=20)

# %%
result1 = api.txt2img(prompt="Anime Character walking",
                    negative_prompt="ugly, out of frame",
                    seed=-1,
                    cfg_scale=7,
                    )
result1.image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>
