# %%
import sys
sys.path.append('./diffusechain')

# %%
from diffusechain import Automatic1111

api = Automatic1111(baseurl='http://localhost:7860')
#or
# api = Automatic1111(host='localhost', port=7860 ,use_https=False)
# Out:
# http://localhost:7860/sdapi/v1

# %%
result1 = api.txt2img(prompt="Elon musk",
                    negative_prompt="ugly, out of frame",
                    seed=-1,
                    cfg_scale=7,
                    steps=30,
                    )
result1.image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
result1.image.save('elon_musk.png')
